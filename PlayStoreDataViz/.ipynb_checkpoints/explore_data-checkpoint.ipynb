# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # this is used for the plot the graph 
import seaborn as sns # used for plot interactive graph.

import matplotlib.pyplot as plt
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go

import warnings
warnings.filterwarnings('ignore')
from pylab import rcParams
# figure size in inches

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
## Read file

# data = pd.read_csv('data/2019-08-26-TOP_PAID-GAME_PUZZLE', sep=',', engine='python')
data1 = pd.read_csv('data/2019-08-26-TOP_FREE-GAME_PUZZLE', sep=',', engine='python')
data2 = pd.read_csv('data/2019-08-26-TOP_GROSSING-GAME_PUZZLE', sep=',', engine='python')
data3 = pd.read_csv('data/2019-08-26-TOP_PAID-GAME_PUZZLE', sep=',', engine='python')

data = pd.concat([data1, data2, data3], ignore_index=True)

# %%
data.columns
# Out:
# Index(['app_id', 'developer_id', 'video', 'current_version', 'screenshots',
#        'developer_url', 'size', 'category', 'recent_changes',
#        'description_html', 'title', 'developer_email', 'interactive_elements',
#        'score', 'developer', 'iap', 'updated', 'description', 'price', 'free',
#        'histogram', 'required_android_version', 'editors_choice', 'icon',
#        'iap_range', 'url', 'content_rating', 'reviews', 'installs'],
#       dtype='object')

# %%
data.head()
# Out:
#                              app_id         developer_id  \
# 0    com.boombitgames.BridgeLowpoly  5496592682158177981
# 1               com.ogurecapps.box2  9164312557033604636
# 2        com.bigduckgames.flowhexes  5251530371678806790
# 3  com.gramgames.london.tentencolor  8000319753740505601
# 4      com.shootbubble.bubbledexlue       City+Games+LLC
#
#                                        video current_version screenshots  \
# 0  https://www.youtube.com/embed/dAxUhmUkEMg           3.1.1          []
# 1                                        NaN          9.7.22          []
# 2                                        NaN             2.1          []
# 3  https://www.youtube.com/embed/Id1-vgCOS2w           1.3.0          []
# 4                                        NaN             4.4          []
#
#                                    developer_url  size         category  \
# 0                   http://www.boombitgames.com/   65M  ['GAME_PUZZLE']
# 1                 http://ogurecapps.blogspot.com   36M  ['GAME_PUZZLE']
# 2                    http://www.bigduckgames.com   11M  ['GAME_PUZZLE']
# 3                                 http://gram.gs   38M  ['GAME_PUZZLE']
# 4  http://www.citygamesllc.com/privacypolicy.htm  2.3M  ['GAME_PUZZLE']
#
#    recent_changes  description_html      ...       free  \
# 0             NaN               NaN      ...       True
# 1             NaN               NaN      ...       True
# 2             NaN               NaN      ...       True
# 3             NaN               NaN      ...       True
# 4             NaN               NaN      ...       True
#
#                                        histogram required_android_version  \
# 0  {1: None, 2: None, 3: None, 4: None, 5: None}               4.1 and up
# 1  {1: None, 2: None, 3: None, 4: None, 5: None}             4.0.3 and up
# 2  {1: None, 2: None, 3: None, 4: None, 5: None}               4.1 and up
# 3  {1: None, 2: None, 3: None, 4: None, 5: None}               4.1 and up
# 4  {1: None, 2: None, 3: None, 4: None, 5: None}               1.1 and up
#
#    editors_choice                                               icon  \
# 0            True  https://lh3.googleusercontent.com/5DApnEIJ-gBE...
# 1           False  https://lh3.googleusercontent.com/EGtGVtETelos...
# 2           False  https://lh3.googleusercontent.com/AlUUBTljis7a...
# 3           False  https://lh3.googleusercontent.com/xrKxHDZXPRcg...
# 4           False  https://lh3.googleusercontent.com/4ek8rG7i-KP-...
#
#                iap_range                                                url  \
# 0    ('$0.99', '$34.99')  https://play.google.com/store/apps/details?id=...
# 1  ['Digital Purchases']  https://play.google.com/store/apps/details?id=...
# 2     ('$0.99', '$3.99')  https://play.google.com/store/apps/details?id=...
# 3           ['Everyone']  https://play.google.com/store/apps/details?id=...
# 4                    NaN  https://play.google.com/store/apps/details?id=...
#
#    content_rating reviews      installs
# 0    ['Everyone']  349266   10,000,000+
# 1    ['Everyone']    9615    1,000,000+
# 2    ['Everyone']   33191    5,000,000+
# 3    ['Everyone']    5173    1,000,000+
# 4    ['Everyone']  903806  100,000,000+
#
# [5 rows x 29 columns]

# %%
#missing data
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(10)
# Out:
#                       Total   Percent
# recent_changes         1657  1.000000
# description            1657  1.000000
# description_html       1657  1.000000
# interactive_elements    763  0.460471
# video                   578  0.348823
# iap_range               551  0.332529
# score                    61  0.036814
# developer_url            23  0.013881
# installs                  0  0.000000
# developer_id              0  0.000000

# %%
def get_main_content_rating (row):
   return row['content_rating'].split('\'')[1]

data['content_rating_main'] = data.apply (lambda row: get_main_content_rating(row), axis=1)

data['content_rating_main']
data['content_rating_main'].value_counts()
# Out:
# Everyone        1463
# Teen             119
# Everyone 10+      68
# Mature 17+         7
# Name: content_rating_main, dtype: int64

# %%
g = sns.catplot(x="content_rating_main",y="score",data=data, kind="box", height = 10 ,palette = "Paired")
g.despine(left=True)
g.set_xticklabels(rotation=90)
g = g.set_ylabels("score")
plt.title('Box plot Score VS Content Rating',size = 20)
g.savefig("output/score_vs_content-rating.png")

# %%
data['iap_range'].describe()
# Out:
# count                    1106
# unique                    161
# top       ('$0.99', '$99.99')
# freq                      291
# Name: iap_range, dtype: object

# %%
# rating distibution 
rcParams['figure.figsize'] = 11.7,8.27
g = sns.kdeplot(data.score, color="Red", shade = True)
g.set_xlabel("Rating")
g.set_ylabel("Frequency")
plt.title('Distribution of Rating',size = 20)

fig = g.get_figure()
fig.savefig('output/distribution-of-rating.png')

# %%
print( len(data['category'].unique()) , "categories")

print("\n", data['category'].unique())
# Out:
# 6 categories
#
#  ["['GAME_PUZZLE']" "['GAME_PUZZLE', 'FAMILY_BRAINGAMES']"
#  "['GAME_PUZZLE', 'FAMILY_CREATE']" "['GAME_PUZZLE', 'FAMILY_EDUCATION']"
#  "['GAME_PUZZLE', 'FAMILY_ACTION']" "['GAME_PUZZLE', 'FAMILY_PRETEND']"]

# %%
g = sns.countplot(x="category",data=data, palette = "Set1")
g.set_xticklabels(g.get_xticklabels(), rotation=90, ha="right")
g 
plt.title('Count of app in each category',size = 20)

fig = g.get_figure()
fig.savefig('output/count-of-categories.png')

# %%
data['reviews'].head()
# Out:
# 0    349266
# 1      9615
# 2     33191
# 3      5173
# 4    903806
# Name: reviews, dtype: int64

# %%
# rating distibution 
rcParams['figure.figsize'] = 11.7,8.27
g = sns.kdeplot(data.reviews, color="Green", shade = True)
g.set_xlabel("reviews")
g.set_ylabel("Frequency")
plt.title('Distribution of Reviews',size = 20)

fig = g.get_figure()
fig.savefig('output/distribution-of-reviews.png')

# %%
plt.figure(figsize = (10,10))
g = sns.jointplot(x="reviews", y="score",color = 'orange', data=data,size = 8);

g.savefig('output/score_vs_reviews.png')

# %%
plt.figure(figsize = (10,10))
sns.regplot(x="reviews", y="score", color = 'darkorange',data=data[data['reviews']<1000000]);
plt.title('Rating VS Reveiws',size = 20)

plt.savefig('output/rating_vs_reviews.png')

# %%
data.price.unique()
# Out:
# array([0, '0', '$4.99', '$3.99', '$1.99', '$6.99', '$0.99', '$2.99',
#        '$5.99', '$3.49', '$9.99', '$99.99', '$4.49', '$13.60', '$1.49',
#        '$2.49', '$1.77', '$3.41', '$1.00', '$9.49', '$1.62', '$8.99',
#        '$1.59', '$1.01', '$4.00', '$5.49', '$1.50', '$1.03', '$2.00',
#        '$2.66', '$29.99', '$1.20', '$1.98'], dtype=object)

# %%
data['price'].value_counts().head(30)
# Out:
# 0         595
# 0         558
# $0.99     147
# $1.99     133
# $2.99      63
# $4.99      51
# $3.99      30
# $1.49      20
# $2.49      13
# $5.99       8
# $3.49       7
# $1.00       4
# $9.99       3
# $4.49       2
# $2.00       2
# $1.01       2
# $8.99       2
# $6.99       2
# $1.77       1
# $1.50       1
# $2.66       1
# $1.62       1
# $5.49       1
# $1.03       1
# $3.41       1
# $4.00       1
# $13.60      1
# $99.99      1
# $1.20       1
# $9.49       1
# Name: price, dtype: int64

# %%
data.price = data.price.apply(lambda x: x.replace('$','') if isinstance(x, str) else x)
data['price'] = data['price'].apply(lambda x: float(x))

# %%
price_df = data[(data['price'] < 50) &  (data['price'] > 0)]

# rating distibution 
rcParams['figure.figsize'] = 11.7,8.27
g = sns.kdeplot(price_df.price, color="Blue", shade = True)
g.set_xlabel("Price")
g.set_ylabel("Frequency")
plt.title('Distribution of Price',size = 20)

fig = g.get_figure()
fig.savefig('output/distribution-of-price.png')

# %%
price_df = data[(data['price'] < 50)]

# rating distibution 
rcParams['figure.figsize'] = 11.7,8.27
g = sns.kdeplot(price_df.price, color="Blue", shade = True)
g.set_xlabel("Price")
g.set_ylabel("Frequency")
plt.title('Distribution of Price',size = 20)

fig = g.get_figure()
fig.savefig('output/distribution-of-price-including-0.png')

# %%
data['price'].describe()
# Out:
# count    1657.000000
# mean        0.825305
# std         2.930095
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.990000
# max        99.990000
# Name: price, dtype: float64

# %%
data[data['price'] == data['price'].describe()['max']]
# Out:
#                                      app_id developer_id video  \
# 1108  com.SmallGamesCompany.currentsequence      BellaSH   NaN
#
#      current_version screenshots  \
# 1108             0.1          []
#
#                                           developer_url size         category  \
# 1108  https://sites.google.com/view/currentsequence/...  28M  ['GAME_PUZZLE']
#
#       recent_changes  description_html         ...           \
# 1108             NaN               NaN         ...
#
#                                           histogram required_android_version  \
# 1108  {1: None, 2: None, 3: None, 4: None, 5: None}               4.1 and up
#
#      editors_choice                                               icon  \
# 1108          False  https://lh3.googleusercontent.com/aNmuWfGB9Qpb...
#
#      iap_range                                                url  \
# 1108       NaN  https://play.google.com/store/apps/details?id=...
#
#      content_rating  reviews  installs  content_rating_main
# 1108   ['Everyone']        4        5+             Everyone
#
# [1 rows x 30 columns]

# %%
plt.figure(figsize = (10,10))
sns.regplot(x="price", y="score", color = 'darkorange',data=data[data['price']<50]);
plt.title('Scatter plot Score VS Price',size = 20)

plt.savefig('output/score_vs_price.png')

# %%
data.loc[ data['price'] == 0, 'PriceBand'] = '0 Free'
data.loc[(data['price'] > 0) & (data['price'] <= 0.99), 'PriceBand'] = '1 cheap'
data.loc[(data['price'] > 0.99) & (data['price'] <= 2.99), 'PriceBand']   = '2 not cheap'
data.loc[(data['price'] > 2.99) & (data['price'] <= 4.99), 'PriceBand']   = '3 normal'
data.loc[(data['price'] > 4.99) & (data['price'] <= 14.99), 'PriceBand']   = '4 expensive'
data.loc[(data['price'] > 14.99), 'PriceBand']   = '5 too expensive'

# %%
data[['PriceBand', 'score']].groupby(['PriceBand'], as_index=False).mean()
# Out:
#          PriceBand     score
# 0           0 Free  4.385069
# 1          1 cheap  4.288889
# 2      2 not cheap  4.499103
# 3         3 normal  4.512941
# 4      4 expensive  4.466667
# 5  5 too expensive  2.000000

# %%
g = sns.catplot(x="PriceBand",y="score",data=data, kind="boxen", height = 10 ,palette = "Pastel1")
g.despine(left=True)
g.set_xticklabels(rotation=90)
g = g.set_ylabels("score")
plt.title('Boxen plot Score VS PriceBand',size = 20)

g.savefig('output/score_vs_priceband.png')

# %%
g = sns.countplot(x="PriceBand",data=data, palette = "Set1")
g.set_xticklabels(g.get_xticklabels(), rotation=90, ha="right")
g 
plt.title('Count of app in each price band',size = 20)

fig = g.get_figure()
fig.savefig('output/count-of-pricebands.png')
